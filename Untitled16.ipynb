# %% [markdown]
# <a href="https://colab.research.google.com/github/sonu860/sonu860/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
batter = pd.read_csv('/content/batter (1).csv')

# %%
batter.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
fig, ax = plt.subplots()  # default is 1 row, 1 col
ax.plot([1, 2, 3], [4, 5, 6])
ax.set_title("Single Plot")

plt.show()

# %%
fig , ax = plt.subplots()
ax.plot(batter['avg'], batter['strike_rate'], marker='o', linestyle='-', color='green')
ax.set_title('Line Plot: Avg vs Strike Rate')
ax.set_xlabel('Average')
ax.set_ylabel('Strike Rate')
# Out:
# Text(0, 0.5, 'Strike Rate')

# %%
temp_df = batter.query("batter in ['RG Sharma', 'V Kohli']")
temp_df
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 3  RG Sharma  5881  30.314433   126.964594

# %%
fig , ax = plt.subplots(1,2)
ax[0].plot(temp_df['avg'], temp_df['strike_rate'], marker='o', linestyle='-', color='green')
ax[1].plot(temp_df['avg'], temp_df['strike_rate'], marker='o', linestyle='-', color='green')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Grid data
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))  # some 3D function

# Create 3D figure
ax = plt.subplot(111, projection='3d')

# Plot surface
surf = ax.plot_surface(X, Y, Z, cmap='viridis')

# Add color bar
fig.colorbar(surf)

# Labels
ax.set_title("3D Surface Plot")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")

plt.show()
# Out:
# <ipython-input-59-38f63d777cb0>:18: UserWarning: Adding colorbar to a different Figure <Figure size 640x480 with 2 Axes> than <Figure size 1000x600 with 2 Axes> which fig.colorbar is called on.
#   fig.colorbar(surf)

# %%
import matplotlib.pyplot as plt

# Data
sizes = [25, 35, 20, 20]
labels = ['A', 'B', 'C', 'D']

# Pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

# Custom text on the plot using plt.text()
plt.text(0, 0, "Center Text",  fontsize=12, color='red')

# Show
plt.title("Pie Chart with Custom Text")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Create grid
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)

# Step 2: Create function Z = f(X, Y)
Z = np.sin(X**2 + Y**2)

# Step 3: Contour plot
plt.contourf(X, Y, Z, cmap='viridis')
plt.title("Contour Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.colorbar(label="Z value")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame
data = pd.DataFrame({
    'Math': [80, 70, 90],
    'Science': [75, 85, 95],
    'English': [60, 65, 70]
}, index=['Student A', 'Student B', 'Student C'])

# Heatmap
sns.heatmap(data, annot=True, cmap='YlGnBu')
plt.title("Student Scores Heatmap")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random matrix
data = np.random.rand(5, 5)

plt.imshow(data, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title("Heatmap with imshow()")
plt.show()
